# %%
# Importo las bibliotecas a utilizar
import numpy
import matplotlib.pyplot as plt
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
import argparse

# %%
numpy.random.seed(7)

# %%
def create_dataset(dataset, look_back=1):
    """
    Se generan los instantes en tiempos t hacia atras
    para lograr predecir el instante t

    :param dataset: conjunto de datos completos
    :param look_back: cuantos instantes de tiempo t hacia atras seran utilizados
    :return: una matriz con los instantes de tiempo hacia atras y el instante presente
    """

    dataX = []
    dataY = []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
def remuestre(cantidad, dataframe):
    """
    Se hace un re muestreo en el dataframe disminuyendo la cantidad total
    de datos
    :param cantidad: cantidad de datos que seran promediados
    :param dataframe: el dataframe con el que se esta trabajando
    :return: dataframe: es el dataframe ya remuestrado
    """
    suma = 0
    contador = 0
    eliminar = []
    for i in range(len(dataframe)):
        contador += 1
        suma += dataframe.loc[i]
        if (contador == cantidad):
            dataframe.loc[i] = suma / cantidad
            contador = 0
            suma = 0
        else:
            eliminar.append(i)
    dataframe = dataframe.drop(dataframe.index[eliminar])
    return dataframe

# %%
def execute_lstm(unidades, date, look_back, neuronas, epocas, capas='6', training_split=0.67,optimizacion='adam', act='tanh'):    
    """
    función que reune la lógica de construcción, entrenamiento y test de la red recurrente LSTM
    """
    
    # normalizacion del dataset
    scaler = MinMaxScaler(feature_range=(0, 1))
    unidades = scaler.fit_transform(unidades)
    date = scaler.fit_transform(date)

    keras.callbacks.Callback()
    train_size = int(len(date) * training_split)
    test_size = len(date) - train_size
    date_train, date_test = date[0:train_size, :], date[train_size:len(date), :]
    unidades_train, unidades_test = unidades[0:train_size, :], unidades[train_size:len(unidades), :]
    print(len(date_train), len(unidades_test))

    date_train_lookback, date_train_tiempo_actual = create_dataset(date_train, look_back)  # date_train_lookback es la presion Entrenamiento
    date_test_lookback, date_test_tiempo_actual = create_dataset(date_test, look_back)  # date_test_lookback es la presion de test
    unidades_train_lookback, unidades_train_tiempo_actual = create_dataset(unidades_train, look_back)  # unidades_train_tiempo_actual autorregulacion de entrenamiento
    unidades_test_lookback, unidades_test_tiempo_actual = create_dataset(unidades_test, look_back)  # unidades_test_tiempo_actual autorregulacion de test

    #transformacion necesaria, para ser utilizados los datos para entrar a la red neuronal
    date_train_lookback = numpy.reshape(date_train_lookback, (date_train_lookback.shape[0], 1, date_train_lookback.shape[1]))
    date_test_lookback = numpy.reshape(date_test_lookback, (date_test_lookback.shape[0], 1, date_test_lookback.shape[1]))

    # create and fit the LSTM network
    csv_logger = keras.callbacks.CSVLogger('training.log', separator=',', append=False)
    model = Sequential()
    model.add(LSTM(neuronas, return_sequences = True, input_shape=(1, look_back)))
    for i in range(capas):
        model.add(LSTM(neuronas, return_sequences = True, activation=act))
    model.add(LSTM(neuronas))
    model.add(Dense(1, activation=act))
    model.compile(loss='mean_squared_error', optimizer=optimizacion)
    model.fit(date_train_lookback, unidades_train_tiempo_actual, epochs=epocas, batch_size=32, verbose=2, callbacks=[csv_logger])

    trainPredict = model.predict(date_train_lookback)
    testPredict = model.predict(date_test_lookback)

    corr = numpy.corrcoef(unidades_test_tiempo_actual, testPredict[:, 0])
    print('Test Score: %.2f CORRELACION' % (corr[1][0]))

    trainPredictPlot = numpy.empty_like(unidades)
    trainPredictPlot[:, :] = numpy.nan
    trainPredictPlot[look_back:len(trainPredict) + look_back, :] = trainPredict

    testPredictPlot = numpy.empty_like(unidades)
    testPredictPlot[:, :] = numpy.nan
    testPredictPlot[len(trainPredict) + (look_back * 2) - 1 :len(unidades) - 1, :] = testPredict

    plt.plot(unidades)
    plt.plot(trainPredictPlot)
    plt.plot(testPredictPlot)
    plt.title("LSTM con %i neuronas, correlacion: %.2f" % (neuronas, corr[1][0] * 100))
    plt.ylabel("Unidades de Carne Vendidas")
    plt.xlabel("Tiempo")
    plt.show()

    registro = pandas.read_csv('training.log', sep=",")
    plt.plot(registro["epoch"].values, registro["loss"].values)
    plt.title("Error LSTM con %i neuronas, correlacion: %.2f" % (neuronas, corr[1][0] * 100))
    plt.ylabel("Error")
    plt.xlabel("Epocas")
    plt.show()
    
    return model, trainPredict, testPredict, scaler

# %%
# TRATAMIENTO DE DATOS
data = pandas.read_csv('data/DATOS_TRATADOS_CON_FECHAS_INT.csv')

# %%
data
# Out:
#       ANO  MES  DIA    UNIDADES  DIA_SEMANA  FECHAS_IMPORT
# 0    2016    1    2  125.585999           6              0
# 1    2016    1    3   70.968002           7              0
# 2    2016    1    4   36.124001           1              0
# 3    2016    1    5   87.123001           2              0
# 4    2016    1    6   42.476002           3              0
# ..    ...  ...  ...         ...         ...            ...
# 974  2018   10   27  261.881988           6              0
# 975  2018   10   28   43.129002           7              0
# 976  2018   10   29   32.816002           1              0
# 977  2018   10   30   55.976002           2              0
# 978  2018   10   31   90.408997           3              1
#
# [979 rows x 6 columns]

# %%
unidades = pandas.DataFrame(data['UNIDADES'])
unidades = unidades.values
unidades = unidades.astype('float32')

date = pandas.DataFrame(data["DIA_SEMANA"])
date['DIA'] = data["DIA"]
date['ANO'] = data["ANO"]
date['MES'] = data["MES"]
date['FECHAS_IMPORT']=data["FECHAS_IMPORT"]
date = date.values
date = date.astype('float32')

# %% [markdown]
# ## ARQUITECTURA NEURONAL
# - Ventana de tiempo (look_back) de 3 meses
# - 200 neuronas
# - 200 epocas de entrenamiento
# - Función de optimización adam
# - Función de activación tanh
# - Entrenamiento y test:
#     - Validación cruzada 70% - 30%
#
# ### Resultado:
# - Correlación de un 42.35%
# - Modelo:
# ![image.png](attachment:image.png)

# %% [markdown]
# - Error:
# ![image.png](attachment:image.png)

# %%
## EJECUCIÓN DE LA FUNCIÓN DE CONSTRUCCIÓN, ENTRENAMIENTO Y TEST DE LA RED
execute_lstm(unidades, date, look_back=90, neuronas=200, epocas=200, capas=6, training_split=0.7,optimizacion='adam', act='tanh')
# Out:
# 685 294
# 2022-01-11 20:50:31.039285: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 19/19 - 10s - loss: 0.0228 - 10s/epoch - 516ms/step
# Epoch 2/200
# 19/19 - 0s - loss: 0.0176 - 385ms/epoch - 20ms/step
# Epoch 3/200
# 19/19 - 1s - loss: 0.0177 - 552ms/epoch - 29ms/step
# Epoch 4/200
# 19/19 - 1s - loss: 0.0177 - 508ms/epoch - 27ms/step
# Epoch 5/200
# 19/19 - 1s - loss: 0.0176 - 521ms/epoch - 27ms/step
# Epoch 6/200
# 19/19 - 1s - loss: 0.0178 - 554ms/epoch - 29ms/step
# Epoch 7/200
# 19/19 - 1s - loss: 0.0178 - 529ms/epoch - 28ms/step
# Epoch 8/200
# 19/19 - 1s - loss: 0.0177 - 515ms/epoch - 27ms/step
# Epoch 9/200
# 19/19 - 0s - loss: 0.0177 - 497ms/epoch - 26ms/step
# Epoch 10/200
# 19/19 - 0s - loss: 0.0177 - 354ms/epoch - 19ms/step
# Epoch 11/200
# 19/19 - 0s - loss: 0.0177 - 406ms/epoch - 21ms/step
# Epoch 12/200
# 19/19 - 0s - loss: 0.0177 - 393ms/epoch - 21ms/step
# Epoch 13/200
# 19/19 - 0s - loss: 0.0177 - 447ms/epoch - 24ms/step
# Epoch 14/200
# 19/19 - 0s - loss: 0.0176 - 380ms/epoch - 20ms/step
# Epoch 15/200
# 19/19 - 0s - loss: 0.0178 - 327ms/epoch - 17ms/step
# Epoch 16/200
# 19/19 - 0s - loss: 0.0177 - 341ms/epoch - 18ms/step
# Epoch 17/200
# 19/19 - 0s - loss: 0.0177 - 481ms/epoch - 25ms/step
# Epoch 18/200
# 19/19 - 0s - loss: 0.0177 - 345ms/epoch - 18ms/step
# Epoch 19/200
# 19/19 - 0s - loss: 0.0177 - 367ms/epoch - 19ms/step
# Epoch 20/200
# 19/19 - 0s - loss: 0.0178 - 385ms/epoch - 20ms/step
# Epoch 21/200
# 19/19 - 0s - loss: 0.0177 - 354ms/epoch - 19ms/step
# Epoch 22/200
# 19/19 - 0s - loss: 0.0178 - 347ms/epoch - 18ms/step
# Epoch 23/200
# 19/19 - 0s - loss: 0.0177 - 403ms/epoch - 21ms/step
# Epoch 24/200
# 19/19 - 0s - loss: 0.0177 - 393ms/epoch - 21ms/step
# Epoch 25/200
# 19/19 - 0s - loss: 0.0177 - 452ms/epoch - 24ms/step
# Epoch 26/200
# 19/19 - 0s - loss: 0.0177 - 242ms/epoch - 13ms/step
# Epoch 27/200
# 19/19 - 0s - loss: 0.0177 - 375ms/epoch - 20ms/step
# Epoch 28/200
# 19/19 - 0s - loss: 0.0172 - 357ms/epoch - 19ms/step
# Epoch 29/200
# 19/19 - 0s - loss: 0.0174 - 267ms/epoch - 14ms/step
# Epoch 30/200
# 19/19 - 0s - loss: 0.0157 - 471ms/epoch - 25ms/step
# Epoch 31/200
# 19/19 - 0s - loss: 0.0152 - 241ms/epoch - 13ms/step
# Epoch 32/200
# 19/19 - 0s - loss: 0.0156 - 238ms/epoch - 13ms/step
# Epoch 33/200
# 19/19 - 0s - loss: 0.0150 - 443ms/epoch - 23ms/step
# Epoch 34/200
# 19/19 - 1s - loss: 0.0155 - 629ms/epoch - 33ms/step
# Epoch 35/200
# 19/19 - 0s - loss: 0.0149 - 446ms/epoch - 23ms/step
# Epoch 36/200
# 19/19 - 0s - loss: 0.0147 - 244ms/epoch - 13ms/step
# Epoch 37/200
# 19/19 - 0s - loss: 0.0151 - 310ms/epoch - 16ms/step
# Epoch 38/200
# 19/19 - 0s - loss: 0.0152 - 340ms/epoch - 18ms/step
# Epoch 39/200
# 19/19 - 0s - loss: 0.0152 - 254ms/epoch - 13ms/step
# Epoch 40/200
# 19/19 - 0s - loss: 0.0146 - 245ms/epoch - 13ms/step
# Epoch 41/200
# 19/19 - 0s - loss: 0.0144 - 294ms/epoch - 15ms/step
# Epoch 42/200
# 19/19 - 1s - loss: 0.0144 - 537ms/epoch - 28ms/step
# Epoch 43/200
# 19/19 - 0s - loss: 0.0146 - 447ms/epoch - 24ms/step
# Epoch 44/200
# 19/19 - 1s - loss: 0.0145 - 522ms/epoch - 27ms/step
# Epoch 45/200
# 19/19 - 0s - loss: 0.0148 - 437ms/epoch - 23ms/step
# Epoch 46/200
# 19/19 - 0s - loss: 0.0143 - 421ms/epoch - 22ms/step
# Epoch 47/200
# 19/19 - 0s - loss: 0.0142 - 231ms/epoch - 12ms/step
# Epoch 48/200
# 19/19 - 0s - loss: 0.0143 - 374ms/epoch - 20ms/step
# Epoch 49/200
# 19/19 - 0s - loss: 0.0143 - 342ms/epoch - 18ms/step
# Epoch 50/200
# 19/19 - 0s - loss: 0.0143 - 244ms/epoch - 13ms/step
# Epoch 51/200
# 19/19 - 0s - loss: 0.0147 - 360ms/epoch - 19ms/step
# Epoch 52/200
# 19/19 - 0s - loss: 0.0141 - 285ms/epoch - 15ms/step
# Epoch 53/200
# 19/19 - 0s - loss: 0.0136 - 241ms/epoch - 13ms/step
# Epoch 54/200
# 19/19 - 0s - loss: 0.0141 - 227ms/epoch - 12ms/step
# Epoch 55/200
# 19/19 - 0s - loss: 0.0139 - 306ms/epoch - 16ms/step
# Epoch 56/200
# 19/19 - 0s - loss: 0.0137 - 245ms/epoch - 13ms/step
# Epoch 57/200
# 19/19 - 0s - loss: 0.0139 - 289ms/epoch - 15ms/step
# Epoch 58/200
# 19/19 - 0s - loss: 0.0138 - 242ms/epoch - 13ms/step
# Epoch 59/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/ws/sp1qfps14rj2wpf5_71gh44m0000gn/T/ipykernel_1553/1350942646.py in <module>
#       1 ## EJECUCIÓN DE LA FUNCIÓN DE CONSTRUCCIÓN, ENTRENAMIENTO Y TEST DE LA RED
# ----> 2 execute_lstm(unidades, date, look_back=90, neuronas=200, epocas=200, capas=6, training_split=0.7,optimizacion='adam', act='tanh')
#
# /var/folders/ws/sp1qfps14rj2wpf5_71gh44m0000gn/T/ipykernel_1553/2052858081.py in execute_lstm(unidades, date, look_back, neuronas, epocas, capas, training_split, optimizacion, act)
#      34     model.add(Dense(1, activation=act))
#      35     model.compile(loss='mean_squared_error', optimizer=optimizacion)
# ---> 36     model.fit(date_train_lookback, unidades_train_tiempo_actual, epochs=epocas, batch_size=32, verbose=2, callbacks=[csv_logger])
#      37
#      38     trainPredict = model.predict(date_train_lookback)
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# /opt/anaconda3/envs/aves/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## ARQUITECTURA NEURONAL
# - Ventana de tiempo (look_back) de 6 meses
# - 200 neuronas
# - 200 epocas de entrenamiento
# - Función de optimización adam
# - Función de activación tanh
# - Entrenamiento y test:
#     - Validación cruzada 70% - 30%
#
# ### Resultado:
# - Correlación de un 49.20%
# - Modelo:
# ![image.png](attachment:image.png)

# %% [markdown]
# - Error:
# ![image.png](attachment:image.png)

# %%
## EJECUCIÓN DE LA FUNCIÓN DE CONSTRUCCIÓN, ENTRENAMIENTO Y TEST DE LA RED
execute_lstm(unidades, date, look_back=180, neuronas=200, epocas=200, capas=6, training_split=0.7,optimizacion='adam', act='tanh')

##
# Out:
# 685 294
# Epoch 1/200
#  - 25s - loss: 0.0251
# Epoch 2/200
#  - 3s - loss: 0.0195
# Epoch 3/200
#  - 3s - loss: 0.0191
# Epoch 4/200
#  - 3s - loss: 0.0192
# Epoch 5/200
#  - 4s - loss: 0.0191
# Epoch 6/200
#  - 3s - loss: 0.0191
# Epoch 7/200
#  - 3s - loss: 0.0191
# Epoch 8/200
#  - 4s - loss: 0.0191
# Epoch 9/200
#  - 4s - loss: 0.0192
# Epoch 10/200
#  - 3s - loss: 0.0192
# Epoch 11/200
#  - 4s - loss: 0.0193
# Epoch 12/200
#  - 5s - loss: 0.0193
# Epoch 13/200
#  - 5s - loss: 0.0191
# Epoch 14/200
#  - 5s - loss: 0.0192
# Epoch 15/200
#  - 4s - loss: 0.0191
# Epoch 16/200
#  - 4s - loss: 0.0191
# Epoch 17/200
#  - 4s - loss: 0.0192
# Epoch 18/200
#  - 4s - loss: 0.0192
# Epoch 19/200
#  - 4s - loss: 0.0193
# Epoch 20/200
#  - 3s - loss: 0.0193
# Epoch 21/200
#  - 3s - loss: 0.0191
# Epoch 22/200
#  - 3s - loss: 0.0191
# Epoch 23/200
#  - 4s - loss: 0.0191
# Epoch 24/200
#  - 3s - loss: 0.0192
# Epoch 25/200
#  - 3s - loss: 0.0192
# Epoch 26/200
#  - 4s - loss: 0.0191
# Epoch 27/200
#  - 4s - loss: 0.0191
# Epoch 28/200
#  - 4s - loss: 0.0191
# Epoch 29/200
#  - 4s - loss: 0.0191
# Epoch 30/200
#  - 3s - loss: 0.0191
# Epoch 31/200
#  - 3s - loss: 0.0191
# Epoch 32/200
#  - 5s - loss: 0.0191
# Epoch 33/200
#  - 4s - loss: 0.0192
# Epoch 34/200
#  - 4s - loss: 0.0191
# Epoch 35/200
#  - 4s - loss: 0.0192
# Epoch 36/200
#  - 4s - loss: 0.0191
# Epoch 37/200
#  - 4s - loss: 0.0191
# Epoch 38/200
#  - 4s - loss: 0.0191
# Epoch 39/200
#  - 3s - loss: 0.0191
# Epoch 40/200
#  - 3s - loss: 0.0191
# Epoch 41/200
#  - 3s - loss: 0.0193
# Epoch 42/200
#  - 3s - loss: 0.0182
# Epoch 43/200
#  - 3s - loss: 0.0179
# Epoch 44/200
#  - 3s - loss: 0.0172
# Epoch 45/200
#  - 3s - loss: 0.0165
# Epoch 46/200
#  - 3s - loss: 0.0157
# Epoch 47/200
#  - 3s - loss: 0.0147
# Epoch 48/200
#  - 3s - loss: 0.0158
# Epoch 49/200
#  - 3s - loss: 0.0154
# Epoch 50/200
#  - 3s - loss: 0.0161
# Epoch 51/200
#  - 3s - loss: 0.0149
# Epoch 52/200
#  - 3s - loss: 0.0146
# Epoch 53/200
#  - 3s - loss: 0.0153
# Epoch 54/200
#  - 3s - loss: 0.0146
# Epoch 55/200
#  - 3s - loss: 0.0135
# Epoch 56/200
#  - 3s - loss: 0.0148
# Epoch 57/200
#  - 3s - loss: 0.0142
# Epoch 58/200
#  - 3s - loss: 0.0141
# Epoch 59/200
#  - 4s - loss: 0.0139
# Epoch 60/200
#  - 3s - loss: 0.0124
# Epoch 61/200
#  - 3s - loss: 0.0121
# Epoch 62/200
#  - 3s - loss: 0.0129
# Epoch 63/200
#  - 4s - loss: 0.0110
# Epoch 64/200
#  - 4s - loss: 0.0123
# Epoch 65/200
#  - 4s - loss: 0.0125
# Epoch 66/200
#  - 3s - loss: 0.0108
# Epoch 67/200
#  - 4s - loss: 0.0107
# Epoch 68/200
#  - 3s - loss: 0.0100
# Epoch 69/200
#  - 4s - loss: 0.0110
# Epoch 70/200
#  - 4s - loss: 0.0122
# Epoch 71/200
#  - 3s - loss: 0.0113
# Epoch 72/200
#  - 3s - loss: 0.0140
# Epoch 73/200
#  - 3s - loss: 0.0099
# Epoch 74/200
#  - 3s - loss: 0.0089
# Epoch 75/200
#  - 3s - loss: 0.0095
# Epoch 76/200
#  - 4s - loss: 0.0096
# Epoch 77/200
#  - 3s - loss: 0.0084
# Epoch 78/200
#  - 3s - loss: 0.0085
# Epoch 79/200
#  - 3s - loss: 0.0083
# Epoch 80/200
#  - 4s - loss: 0.0086
# Epoch 81/200
#  - 4s - loss: 0.0079
# Epoch 82/200
#  - 3s - loss: 0.0093
# Epoch 83/200
#  - 3s - loss: 0.0080
# Epoch 84/200
#  - 3s - loss: 0.0083
# Epoch 85/200
#  - 3s - loss: 0.0076
# Epoch 86/200
#  - 3s - loss: 0.0070
# Epoch 87/200
#  - 3s - loss: 0.0076
# Epoch 88/200
#  - 3s - loss: 0.0076
# Epoch 89/200
#  - 3s - loss: 0.0065
# Epoch 90/200
#  - 3s - loss: 0.0064
# Epoch 91/200
#  - 3s - loss: 0.0065
# Epoch 92/200
#  - 3s - loss: 0.0068
# Epoch 93/200
#  - 3s - loss: 0.0070
# Epoch 94/200
#  - 3s - loss: 0.0067
# Epoch 95/200
#  - 3s - loss: 0.0061
# Epoch 96/200
#  - 3s - loss: 0.0062
# Epoch 97/200
#  - 3s - loss: 0.0076
# Epoch 98/200
#  - 3s - loss: 0.0065
# Epoch 99/200
#  - 3s - loss: 0.0068
# Epoch 100/200
#  - 3s - loss: 0.0057
# Epoch 101/200
#  - 3s - loss: 0.0054
# Epoch 102/200
#  - 3s - loss: 0.0051
# Epoch 103/200
#  - 3s - loss: 0.0051
# Epoch 104/200
#  - 3s - loss: 0.0055
# Epoch 105/200
#  - 3s - loss: 0.0051
# Epoch 106/200
#  - 3s - loss: 0.0047
# Epoch 107/200
#  - 3s - loss: 0.0046
# Epoch 108/200
#  - 3s - loss: 0.0046
# Epoch 109/200
#  - 3s - loss: 0.0045
# Epoch 110/200
#  - 3s - loss: 0.0050
# Epoch 111/200
#  - 3s - loss: 0.0045
# Epoch 112/200
#  - 3s - loss: 0.0039
# Epoch 113/200
#  - 3s - loss: 0.0043
# Epoch 114/200
#  - 3s - loss: 0.0038
# Epoch 115/200
#  - 3s - loss: 0.0045
# Epoch 116/200
#  - 3s - loss: 0.0040
# Epoch 117/200
#  - 3s - loss: 0.0035
# Epoch 118/200
#  - 3s - loss: 0.0036
# Epoch 119/200
#  - 3s - loss: 0.0039
# Epoch 120/200
#  - 3s - loss: 0.0047
# Epoch 121/200
#  - 3s - loss: 0.0048
# Epoch 122/200
#  - 3s - loss: 0.0043
# Epoch 123/200
#  - 3s - loss: 0.0039
# Epoch 124/200
#  - 3s - loss: 0.0033
# Epoch 125/200
#  - 3s - loss: 0.0036
# Epoch 126/200
#  - 3s - loss: 0.0043
# Epoch 127/200
#  - 3s - loss: 0.0042
# Epoch 128/200
#  - 3s - loss: 0.0048
# Epoch 129/200
#  - 3s - loss: 0.0042
# Epoch 130/200
#  - 4s - loss: 0.0056
# Epoch 131/200
#  - 4s - loss: 0.0119
# Epoch 132/200
#  - 3s - loss: 0.0170
# Epoch 133/200
#  - 5s - loss: 0.0137
# Epoch 134/200
#  - 5s - loss: 0.0126
# Epoch 135/200
#  - 4s - loss: 0.0095
# Epoch 136/200
#  - 4s - loss: 0.0077
# Epoch 137/200
#  - 3s - loss: 0.0067
# Epoch 138/200
#  - 3s - loss: 0.0063
# Epoch 139/200
#  - 3s - loss: 0.0035
# Epoch 140/200
#  - 3s - loss: 0.0036
# Epoch 141/200
#  - 3s - loss: 0.0039
# Epoch 142/200
#  - 3s - loss: 0.0032
# Epoch 143/200
#  - 3s - loss: 0.0027
# Epoch 144/200
#  - 3s - loss: 0.0025
# Epoch 145/200
#  - 4s - loss: 0.0024
# Epoch 146/200
#  - 4s - loss: 0.0024
# Epoch 147/200
#  - 4s - loss: 0.0023
# Epoch 148/200
#  - 4s - loss: 0.0021
# Epoch 149/200
#  - 3s - loss: 0.0020
# Epoch 150/200
#  - 3s - loss: 0.0022
# Epoch 151/200
#  - 3s - loss: 0.0020
# Epoch 152/200
#  - 3s - loss: 0.0019
# Epoch 153/200
#  - 3s - loss: 0.0020
# Epoch 154/200
#  - 3s - loss: 0.0021
# Epoch 155/200
#  - 3s - loss: 0.0019
# Epoch 156/200
#  - 3s - loss: 0.0017
# Epoch 157/200
#  - 3s - loss: 0.0018
# Epoch 158/200
#  - 3s - loss: 0.0020
# Epoch 159/200
#  - 3s - loss: 0.0021
# Epoch 160/200
#  - 3s - loss: 0.0021
# Epoch 161/200
#  - 3s - loss: 0.0021
# Epoch 162/200
#  - 3s - loss: 0.0017
# Epoch 163/200
#  - 3s - loss: 0.0016
# Epoch 164/200
#  - 3s - loss: 0.0017
# Epoch 165/200
#  - 3s - loss: 0.0020
# Epoch 166/200
#  - 4s - loss: 0.0020
# Epoch 167/200
#  - 3s - loss: 0.0016
# Epoch 168/200
#  - 3s - loss: 0.0017
# Epoch 169/200
#  - 3s - loss: 0.0015
# Epoch 170/200
#  - 3s - loss: 0.0014
# Epoch 171/200
#  - 3s - loss: 0.0014
# Epoch 172/200
#  - 3s - loss: 0.0015
# Epoch 173/200
#  - 4s - loss: 0.0013
# Epoch 174/200
#  - 3s - loss: 0.0014
# Epoch 175/200
#  - 3s - loss: 0.0015
# Epoch 176/200
#  - 4s - loss: 0.0013
# Epoch 177/200
#  - 3s - loss: 0.0014
# Epoch 178/200
#  - 3s - loss: 0.0014
# Epoch 179/200
#  - 3s - loss: 0.0016
# Epoch 180/200
#  - 3s - loss: 0.0017
# Epoch 181/200
#  - 4s - loss: 0.0014
# Epoch 182/200
#  - 3s - loss: 0.0014
# Epoch 183/200
#  - 4s - loss: 0.0014
# Epoch 184/200
#  - 4s - loss: 0.0014
# Epoch 185/200
#  - 3s - loss: 0.0013
# Epoch 186/200
#  - 3s - loss: 0.0014
# Epoch 187/200
#  - 3s - loss: 0.0016
# Epoch 188/200
#  - 3s - loss: 0.0016
# Epoch 189/200
#  - 3s - loss: 0.0014
# Epoch 190/200
#  - 3s - loss: 0.0014
# Epoch 191/200
#  - 4s - loss: 0.0013
# Epoch 192/200
#  - 4s - loss: 0.0012
# Epoch 193/200
#  - 4s - loss: 0.0015
# Epoch 194/200
#  - 4s - loss: 0.0014
# Epoch 195/200
#  - 4s - loss: 0.0013
# Epoch 196/200
#  - 3s - loss: 0.0012
# Epoch 197/200
#  - 4s - loss: 0.0012
# Epoch 198/200
#  - 4s - loss: 0.0012
# Epoch 199/200
#  - 4s - loss: 0.0012
# Epoch 200/200
#  - 4s - loss: 0.0011
# Test Score: 0.49 CORRELACION

# %% [markdown]
# ## ARQUITECTURA NEURONAL
# - Ventana de tiempo (look_back) de 3 meses
# - 200 neuronas
# - 200 epocas de entrenamiento
# - Función de optimización adam
# - Función de activación tanh
# - Entrenamiento y test:
#     - Validación cruzada 70% - 30%
#
# ### Resultado:
# - Correlación de un 27.31%
# - Modelo:
# ![image.png](attachment:image.png)

# %% [markdown]
# - Error:
# ![image.png](attachment:image.png)

# %%
## EJECUCIÓN DE LA FUNCIÓN DE CONSTRUCCIÓN, ENTRENAMIENTO Y TEST DE LA RED
execute_lstm(unidades, date, look_back=180, neuronas=300, epocas=300, capas=6, training_split=0.7,optimizacion='adam', act='tanh')
##
# Out:
# 685 294
# Epoch 1/300
#  - 46s - loss: 0.0245
# Epoch 2/300
#  - 7s - loss: 0.0191
# Epoch 3/300
#  - 7s - loss: 0.0192
# Epoch 4/300
#  - 8s - loss: 0.0191
# Epoch 5/300
#  - 7s - loss: 0.0191
# Epoch 6/300
#  - 6s - loss: 0.0191
# Epoch 7/300
#  - 6s - loss: 0.0191
# Epoch 8/300
#  - 7s - loss: 0.0191
# Epoch 9/300
#  - 6s - loss: 0.0192
# Epoch 10/300
#  - 6s - loss: 0.0192
# Epoch 11/300
#  - 6s - loss: 0.0193
# Epoch 12/300
#  - 7s - loss: 0.0191
# Epoch 13/300
#  - 8s - loss: 0.0191
# Epoch 14/300
#  - 7s - loss: 0.0191
# Epoch 15/300
#  - 7s - loss: 0.0191
# Epoch 16/300
#  - 8s - loss: 0.0191
# Epoch 17/300
#  - 8s - loss: 0.0191
# Epoch 18/300
#  - 7s - loss: 0.0192
# Epoch 19/300
#  - 6s - loss: 0.0191
# Epoch 20/300
#  - 7s - loss: 0.0191
# Epoch 21/300
#  - 6s - loss: 0.0191
# Epoch 22/300
#  - 8s - loss: 0.0192
# Epoch 23/300
#  - 8s - loss: 0.0193
# Epoch 24/300
#  - 8s - loss: 0.0191
# Epoch 25/300
#  - 8s - loss: 0.0192
# Epoch 26/300
#  - 8s - loss: 0.0194
# Epoch 27/300
#  - 8s - loss: 0.0192
# Epoch 28/300
#  - 9s - loss: 0.0192
# Epoch 29/300
#  - 8s - loss: 0.0192
# Epoch 30/300
#  - 6s - loss: 0.0191
# Epoch 31/300
#  - 7s - loss: 0.0191
# Epoch 32/300
#  - 7s - loss: 0.0191
# Epoch 33/300
#  - 6s - loss: 0.0191
# Epoch 34/300
#  - 6s - loss: 0.0191
# Epoch 35/300
#  - 7s - loss: 0.0191
# Epoch 36/300
#  - 7s - loss: 0.0191
# Epoch 37/300
#  - 7s - loss: 0.0191
# Epoch 38/300
#  - 7s - loss: 0.0191
# Epoch 39/300
#  - 7s - loss: 0.0191
# Epoch 40/300
#  - 7s - loss: 0.0191
# Epoch 41/300
#  - 6s - loss: 0.0191
# Epoch 42/300
#  - 6s - loss: 0.0191
# Epoch 43/300
#  - 6s - loss: 0.0191
# Epoch 44/300
#  - 6s - loss: 0.0191
# Epoch 45/300
#  - 7s - loss: 0.0192
# Epoch 46/300
#  - 7s - loss: 0.0191
# Epoch 47/300
#  - 7s - loss: 0.0186
# Epoch 48/300
#  - 6s - loss: 0.0188
# Epoch 49/300
#  - 6s - loss: 0.0171
# Epoch 50/300
#  - 6s - loss: 0.0167
# Epoch 51/300
#  - 6s - loss: 0.0171
# Epoch 52/300
#  - 7s - loss: 0.0153
# Epoch 53/300
#  - 6s - loss: 0.0148
# Epoch 54/300
#  - 7s - loss: 0.0153
# Epoch 55/300
#  - 7s - loss: 0.0151
# Epoch 56/300
#  - 7s - loss: 0.0145
# Epoch 57/300
#  - 7s - loss: 0.0157
# Epoch 58/300
#  - 7s - loss: 0.0142
# Epoch 59/300
#  - 7s - loss: 0.0144
# Epoch 60/300
#  - 7s - loss: 0.0135
# Epoch 61/300
#  - 7s - loss: 0.0151
# Epoch 62/300
#  - 7s - loss: 0.0151
# Epoch 63/300
#  - 7s - loss: 0.0134
# Epoch 64/300
#  - 7s - loss: 0.0142
# Epoch 65/300
#  - 7s - loss: 0.0151
# Epoch 66/300
#  - 7s - loss: 0.0138
# Epoch 67/300
#  - 9s - loss: 0.0124
# Epoch 68/300
#  - 7s - loss: 0.0124
# Epoch 69/300
#  - 6s - loss: 0.0124
# Epoch 70/300
#  - 6s - loss: 0.0116
# Epoch 71/300
#  - 6s - loss: 0.0115
# Epoch 72/300
#  - 8s - loss: 0.0121
# Epoch 73/300
#  - 7s - loss: 0.0126
# Epoch 74/300
#  - 8s - loss: 0.0107
# Epoch 75/300
#  - 6s - loss: 0.0108
# Epoch 76/300
#  - 6s - loss: 0.0094
# Epoch 77/300
#  - 6s - loss: 0.0091
# Epoch 78/300
#  - 6s - loss: 0.0099
# Epoch 79/300
#  - 7s - loss: 0.0093
# Epoch 80/300
#  - 7s - loss: 0.0090
# Epoch 81/300
#  - 6s - loss: 0.0088
# Epoch 82/300
#  - 6s - loss: 0.0078
# Epoch 83/300
#  - 6s - loss: 0.0086
# Epoch 84/300
#  - 6s - loss: 0.0087
# Epoch 85/300
#  - 6s - loss: 0.0095
# Epoch 86/300
#  - 6s - loss: 0.0112
# Epoch 87/300
#  - 6s - loss: 0.0086
# Epoch 88/300
#  - 6s - loss: 0.0093
# Epoch 89/300
#  - 6s - loss: 0.0082
# Epoch 90/300
#  - 6s - loss: 0.0082
# Epoch 91/300
#  - 6s - loss: 0.0074
# Epoch 92/300
#  - 7s - loss: 0.0067
# Epoch 93/300
#  - 7s - loss: 0.0066
# Epoch 94/300
#  - 7s - loss: 0.0063
# Epoch 95/300
#  - 7s - loss: 0.0061
# Epoch 96/300
#  - 7s - loss: 0.0076
# Epoch 97/300
#  - 7s - loss: 0.0066
# Epoch 98/300
#  - 7s - loss: 0.0066
# Epoch 99/300
#  - 7s - loss: 0.0068
# Epoch 100/300
#  - 7s - loss: 0.0065
# Epoch 101/300
#  - 8s - loss: 0.0064
# Epoch 102/300
#  - 6s - loss: 0.0058
# Epoch 103/300
#  - 6s - loss: 0.0055
# Epoch 104/300
#  - 6s - loss: 0.0060
# Epoch 105/300
#  - 6s - loss: 0.0053
# Epoch 106/300
#  - 6s - loss: 0.0049
# Epoch 107/300
#  - 6s - loss: 0.0062
# Epoch 108/300
#  - 6s - loss: 0.0092
# Epoch 109/300
#  - 6s - loss: 0.0131
# Epoch 110/300
#  - 6s - loss: 0.0111
# Epoch 111/300
#  - 6s - loss: 0.0089
# Epoch 112/300
#  - 6s - loss: 0.0078
# Epoch 113/300
#  - 6s - loss: 0.0060
# Epoch 114/300
#  - 6s - loss: 0.0058
# Epoch 115/300
#  - 6s - loss: 0.0054
# Epoch 116/300
#  - 6s - loss: 0.0097
# Epoch 117/300
#  - 6s - loss: 0.0118
# Epoch 118/300
#  - 6s - loss: 0.0065
# Epoch 119/300
#  - 6s - loss: 0.0056
# Epoch 120/300
#  - 6s - loss: 0.0052
# Epoch 121/300
#  - 7s - loss: 0.0041
# Epoch 122/300
#  - 6s - loss: 0.0044
# Epoch 123/300
#  - 6s - loss: 0.0042
# Epoch 124/300
#  - 6s - loss: 0.0036
# Epoch 125/300
#  - 6s - loss: 0.0039
# Epoch 126/300
#  - 6s - loss: 0.0035
# Epoch 127/300
#  - 6s - loss: 0.0030
# Epoch 128/300
#  - 6s - loss: 0.0030
# Epoch 129/300
#  - 6s - loss: 0.0026
# Epoch 130/300
#  - 6s - loss: 0.0026
# Epoch 131/300
#  - 6s - loss: 0.0026
# Epoch 132/300
#  - 6s - loss: 0.0024
# Epoch 133/300
#  - 6s - loss: 0.0024
# Epoch 134/300
#  - 6s - loss: 0.0025
# Epoch 135/300
#  - 6s - loss: 0.0025
# Epoch 136/300
#  - 6s - loss: 0.0024
# Epoch 137/300
#  - 6s - loss: 0.0021
# Epoch 138/300
#  - 7s - loss: 0.0021
# Epoch 139/300
#  - 6s - loss: 0.0021
# Epoch 140/300
#  - 8s - loss: 0.0021
# Epoch 141/300
#  - 6s - loss: 0.0024
# Epoch 142/300
#  - 6s - loss: 0.0022
# Epoch 143/300
#  - 6s - loss: 0.0022
# Epoch 144/300
#  - 6s - loss: 0.0020
# Epoch 145/300
#  - 6s - loss: 0.0019
# Epoch 146/300
#  - 6s - loss: 0.0020
# Epoch 147/300
#  - 6s - loss: 0.0020
# Epoch 148/300
#  - 6s - loss: 0.0019
# Epoch 149/300
#  - 6s - loss: 0.0020
# Epoch 150/300
#  - 6s - loss: 0.0017
# Epoch 151/300
#  - 6s - loss: 0.0018
# Epoch 152/300
#  - 6s - loss: 0.0016
# Epoch 153/300
#  - 6s - loss: 0.0016
# Epoch 154/300
#  - 6s - loss: 0.0016
# Epoch 155/300
#  - 7s - loss: 0.0016
# Epoch 156/300
#  - 6s - loss: 0.0016
# Epoch 157/300
#  - 6s - loss: 0.0016
# Epoch 158/300
#  - 6s - loss: 0.0017
# Epoch 159/300
#  - 9s - loss: 0.0015
# Epoch 160/300
#  - 9s - loss: 0.0018
# Epoch 161/300
#  - 7s - loss: 0.0019
# Epoch 162/300
#  - 7s - loss: 0.0016
# Epoch 163/300
#  - 6s - loss: 0.0015
# Epoch 164/300
#  - 6s - loss: 0.0014
# Epoch 165/300
#  - 7s - loss: 0.0015
# Epoch 166/300
#  - 6s - loss: 0.0016
# Epoch 167/300
#  - 6s - loss: 0.0014
# Epoch 168/300
#  - 6s - loss: 0.0012
# Epoch 169/300
#  - 6s - loss: 0.0013
# Epoch 170/300
#  - 6s - loss: 0.0013
# Epoch 171/300
#  - 6s - loss: 0.0014
# Epoch 172/300
#  - 6s - loss: 0.0015
# Epoch 173/300
#  - 7s - loss: 0.0016
# Epoch 174/300
#  - 6s - loss: 0.0016
# Epoch 175/300
#  - 6s - loss: 0.0016
# Epoch 176/300
#  - 6s - loss: 0.0014
# Epoch 177/300
#  - 6s - loss: 0.0013
# Epoch 178/300
#  - 6s - loss: 0.0013
# Epoch 179/300
#  - 6s - loss: 0.0013
# Epoch 180/300
#  - 6s - loss: 0.0012
# Epoch 181/300
#  - 6s - loss: 0.0011
# Epoch 182/300
#  - 6s - loss: 0.0013
# Epoch 183/300
#  - 6s - loss: 0.0012
# Epoch 184/300
#  - 6s - loss: 0.0011
# Epoch 185/300
#  - 6s - loss: 0.0012
# Epoch 186/300
#  - 6s - loss: 0.0012
# Epoch 187/300
#  - 6s - loss: 0.0013
# Epoch 188/300
#  - 6s - loss: 0.0013
# Epoch 189/300
#  - 6s - loss: 0.0013
# Epoch 190/300
#  - 6s - loss: 0.0012
# Epoch 191/300
#  - 6s - loss: 0.0012
# Epoch 192/300
#  - 6s - loss: 0.0016
# Epoch 193/300
#  - 6s - loss: 0.0017
# Epoch 194/300
#  - 6s - loss: 0.0015
# Epoch 195/300
#  - 6s - loss: 0.0015
# Epoch 196/300
#  - 6s - loss: 0.0014
# Epoch 197/300
#  - 6s - loss: 0.0012
# Epoch 198/300
#  - 8s - loss: 0.0011
# Epoch 199/300
#  - 6s - loss: 0.0012
# Epoch 200/300
#  - 6s - loss: 0.0012
# Epoch 201/300
#  - 6s - loss: 0.0012
# Epoch 202/300
#  - 6s - loss: 0.0016
# Epoch 203/300
#  - 8s - loss: 0.0018
# Epoch 204/300
#  - 8s - loss: 0.0013
# Epoch 205/300
#  - 7s - loss: 0.0011
# Epoch 206/300
#  - 7s - loss: 0.0010
# Epoch 207/300
#  - 8s - loss: 0.0012
# Epoch 208/300
#  - 7s - loss: 0.0012
# Epoch 209/300
#  - 7s - loss: 9.8212e-04
# Epoch 210/300
#  - 7s - loss: 0.0010
# Epoch 211/300
#  - 8s - loss: 7.9208e-04
# Epoch 212/300
#  - 8s - loss: 7.5301e-04
# Epoch 213/300
#  - 8s - loss: 8.2963e-04
# Epoch 214/300
#  - 8s - loss: 9.4576e-04
# Epoch 215/300
#  - 8s - loss: 9.1824e-04
# Epoch 216/300
#  - 7s - loss: 0.0010
# Epoch 217/300
#  - 7s - loss: 7.7978e-04
# Epoch 218/300
#  - 7s - loss: 7.9899e-04
# Epoch 219/300
#  - 6s - loss: 9.3034e-04
# Epoch 220/300
#  - 8s - loss: 7.1321e-04
# Epoch 221/300
#  - 7s - loss: 6.6451e-04
# Epoch 222/300
#  - 6s - loss: 6.2683e-04
# Epoch 223/300
#  - 7s - loss: 7.3106e-04
# Epoch 224/300
#  - 7s - loss: 6.8689e-04
# Epoch 225/300
#  - 6s - loss: 7.0695e-04
# Epoch 226/300
#  - 7s - loss: 8.6415e-04
# Epoch 227/300
#  - 10s - loss: 8.7619e-04
# Epoch 228/300
#  - 8s - loss: 7.2694e-04
# Epoch 229/300
#  - 7s - loss: 6.4759e-04
# Epoch 230/300
#  - 6s - loss: 5.7014e-04
# Epoch 231/300
#  - 7s - loss: 6.8064e-04
# Epoch 232/300
#  - 7s - loss: 6.0078e-04
# Epoch 233/300
#  - 7s - loss: 6.0157e-04
# Epoch 234/300
#  - 6s - loss: 5.5181e-04
# Epoch 235/300
#  - 7s - loss: 6.0946e-04
# Epoch 236/300
#  - 7s - loss: 6.0096e-04
# Epoch 237/300
#  - 6s - loss: 5.9209e-04
# Epoch 238/300
#  - 6s - loss: 4.9283e-04
# Epoch 239/300
#  - 7s - loss: 4.4324e-04
# Epoch 240/300
#  - 8s - loss: 5.1291e-04
# Epoch 241/300
#  - 7s - loss: 7.3138e-04
# Epoch 242/300
#  - 6s - loss: 8.5020e-04
# Epoch 243/300
#  - 6s - loss: 0.0011
# Epoch 244/300
#  - 7s - loss: 0.0011
# Epoch 245/300
#  - 6s - loss: 7.8062e-04
# Epoch 246/300
#  - 8s - loss: 6.7599e-04
# Epoch 247/300
#  - 7s - loss: 7.7694e-04
# Epoch 248/300
#  - 6s - loss: 7.8493e-04
# Epoch 249/300
#  - 7s - loss: 7.1485e-04
# Epoch 250/300
#  - 7s - loss: 8.1779e-04
# Epoch 251/300
#  - 7s - loss: 6.5855e-04
# Epoch 252/300
#  - 9s - loss: 5.1432e-04
# Epoch 253/300
#  - 9s - loss: 5.2718e-04
# Epoch 254/300
#  - 11s - loss: 3.8694e-04
# Epoch 255/300
#  - 7s - loss: 4.0867e-04
# Epoch 256/300
#  - 7s - loss: 3.8458e-04
# Epoch 257/300
#  - 6s - loss: 4.4437e-04
# Epoch 258/300
#  - 6s - loss: 4.5350e-04
# Epoch 259/300
#  - 7s - loss: 4.5049e-04
# Epoch 260/300
#  - 7s - loss: 4.3760e-04
# Epoch 261/300
#  - 8s - loss: 4.2912e-04
# Epoch 262/300
#  - 8s - loss: 5.5234e-04
# Epoch 263/300
#  - 8s - loss: 4.9689e-04
# Epoch 264/300
#  - 8s - loss: 5.2899e-04
# Epoch 265/300
#  - 6s - loss: 4.6208e-04
# Epoch 266/300
#  - 6s - loss: 4.1284e-04
# Epoch 267/300
#  - 8s - loss: 3.4627e-04
# Epoch 268/300
#  - 8s - loss: 3.9115e-04
# Epoch 269/300
#  - 8s - loss: 4.3224e-04
# Epoch 270/300
#  - 7s - loss: 4.2223e-04
# Epoch 271/300
#  - 8s - loss: 4.6057e-04
# Epoch 272/300
#  - 7s - loss: 4.0943e-04
# Epoch 273/300
#  - 6s - loss: 3.4622e-04
# Epoch 274/300
#  - 7s - loss: 3.6901e-04
# Epoch 275/300
#  - 8s - loss: 3.3923e-04
# Epoch 276/300
#  - 7s - loss: 4.1720e-04
# Epoch 277/300
#  - 7s - loss: 3.1679e-04
# Epoch 278/300
#  - 7s - loss: 3.1341e-04
# Epoch 279/300
#  - 8s - loss: 3.1552e-04
# Epoch 280/300
#  - 7s - loss: 3.5388e-04
# Epoch 281/300
#  - 7s - loss: 3.5404e-04
# Epoch 282/300
#  - 6s - loss: 3.6264e-04
# Epoch 283/300
#  - 6s - loss: 3.2441e-04
# Epoch 284/300
#  - 6s - loss: 3.0620e-04
# Epoch 285/300
#  - 6s - loss: 3.1372e-04
# Epoch 286/300
#  - 6s - loss: 3.1115e-04
# Epoch 287/300
#  - 7s - loss: 3.3214e-04
# Epoch 288/300
#  - 8s - loss: 2.8974e-04
# Epoch 289/300
#  - 7s - loss: 4.7732e-04
# Epoch 290/300
#  - 8s - loss: 5.0978e-04
# Epoch 291/300
#  - 9s - loss: 5.2364e-04
# Epoch 292/300
#  - 8s - loss: 3.3612e-04
# Epoch 293/300
#  - 7s - loss: 3.0949e-04
# Epoch 294/300
#  - 6s - loss: 3.6458e-04
# Epoch 295/300
#  - 7s - loss: 5.6104e-04
# Epoch 296/300
#  - 6s - loss: 8.0764e-04
# Epoch 297/300
#  - 6s - loss: 6.8822e-04
# Epoch 298/300
#  - 6s - loss: 5.7627e-04
# Epoch 299/300
#  - 6s - loss: 5.3050e-04
# Epoch 300/300
#  - 6s - loss: 4.5248e-04
# Test Score: 0.34 CORRELACION
# (<keras.engine.sequential.Sequential at 0x1a737c56d8>, array([[0.24393699],
#         [0.10960165],
#         [0.01246201],
#         [0.06072441],
#         [0.03938556],
#         [0.02477051],
#         [0.13530518],
#         [0.21703245],
#         [0.08111197],
#         [0.09297812],
#         [0.08436394],
#         [0.06756962],
#         [0.08874981],
#         [0.18461196],
#         [0.18213235],
#         [0.09787331],
#         [0.0384469 ],
#         [0.03237284],
#         [0.0476071 ],
#         [0.10829584],
#         [0.17386389],
#         [0.09365351],
#         [0.08682987],
#         [0.02431756],
#         [0.050698  ],
#         [0.02568888],
#         [0.05545476],
#         [0.06091909],
#         [0.10283457],
#         [0.1013932 ],
#         [0.02013931],
#         [0.10993737],
#         [0.05367865],
#         [0.07785369],
#         [0.06776077],
#         [0.10056414],
#         [0.11884747],
#         [0.03078058],
#         [0.05916169],
#         [0.04618275],
#         [0.1303752 ],
#         [0.1757747 ],
#         [0.34117937],
#         [0.24152058],
#         [0.13451427],
#         [0.09894496],
#         [0.05894025],
#         [0.08117491],
#         [0.0722267 ],
#         [0.16858369],
#         [0.12344028],
#         [0.0555407 ],
#         [0.08183721],
#         [0.04578214],
#         [0.06660006],
#         [0.07321944],
#         [0.14235641],
#         [0.1362313 ],
#         [0.07598426],
#         [0.07183556],
#         [0.08004566],
#         [0.08491129],
#         [0.1449642 ],
#         [0.21978818],
#         [0.15843403],
#         [0.09436947],
#         [0.8353722 ],
#         [0.08082964],
#         [0.09030578],
#         [0.12366997],
#         [0.1457802 ],
#         [0.17354915],
#         [0.39945567],
#         [0.9269093 ],
#         [0.81517446],
#         [0.39885855],
#         [0.5433108 ],
#         [0.42161408],
#         [0.06793495],
#         [0.044707  ],
#         [0.00830867],
#         [0.04300221],
#         [0.10887913],
#         [0.06387663],
#         [0.01172263],
#         [0.03352301],
#         [0.02052507],
#         [0.03017151],
#         [0.03257202],
#         [0.11484869],
#         [0.03873146],
#         [0.01347307],
#         [0.02983125],
#         [0.2230734 ],
#         [0.25595227],
#         [0.05230725],
#         [0.08691033],
#         [0.04850411],
#         [0.033791  ],
#         [0.17080767],
#         [0.05902817],
#         [0.05799063],
#         [0.08231571],
#         [0.18396723],
#         [0.06480027],
#         [0.03124431],
#         [0.06271371],
#         [0.05651683],
#         [0.04860374],
#         [0.09163067],
#         [0.10678059],
#         [0.0616551 ],
#         [0.02773166],
#         [0.10121259],
#         [0.0288634 ],
#         [0.08141668],
#         [0.27726713],
#         [0.42938113],
#         [0.27064264],
#         [0.20407939],
#         [0.11356349],
#         [0.02964695],
#         [0.0495357 ],
#         [0.09725055],
#         [0.13556953],
#         [0.06435724],
#         [0.03172313],
#         [0.02502576],
#         [0.02490726],
#         [0.0795082 ],
#         [0.08564048],
#         [0.11372408],
#         [0.06779438],
#         [0.03604648],
#         [0.04022405],
#         [0.02617199],
#         [0.04097278],
#         [0.1255961 ],
#         [0.19214103],
#         [0.10099427],
#         [0.02794174],
#         [0.05060291],
#         [0.05190742],
#         [0.03346388],
#         [0.14787701],
#         [0.18953773],
#         [0.13518661],
#         [0.06030064],
#         [0.05915477],
#         [0.06439789],
#         [0.05808058],
#         [0.20071428],
#         [0.2989318 ],
#         [0.21255599],
#         [0.1526785 ],
#         [0.08747653],
#         [0.13810593],
#         [0.1413664 ],
#         [0.11545016],
#         [0.14648302],
#         [0.13278046],
#         [0.02566992],
#         [0.05761063],
#         [0.0382078 ],
#         [0.0444757 ],
#         [0.05904936],
#         [0.13513818],
#         [0.08536753],
#         [0.02532591],
#         [0.08282892],
#         [0.08193862],
#         [0.12579252],
#         [0.23294039],
#         [0.22283405],
#         [0.08152518],
#         [0.08219927],
#         [0.76155144],
#         [0.7357556 ],
#         [0.30973107],
#         [0.31853133],
#         [0.0540785 ],
#         [0.06037121],
#         [0.03792514],
#         [0.07797657],
#         [0.15871802],
#         [0.15141456],
#         [0.10301074],
#         [0.04399759],
#         [0.0374904 ],
#         [0.2962971 ],
#         [0.08411226],
#         [0.25346732],
#         [0.3344991 ],
#         [0.22085351],
#         [0.1388723 ],
#         [0.14513949],
#         [0.10786702],
#         [0.09690337],
#         [0.28738102],
#         [0.43761727],
#         [0.23235826],
#         [0.11335718],
#         [0.09396207],
#         [0.15089935],
#         [0.09302051],
#         [0.19690768],
#         [0.2823701 ],
#         [0.23190568],
#         [0.02620475],
#         [0.10114066],
#         [0.09645043],
#         [0.08532632],
#         [0.16598734],
#         [0.2918959 ],
#         [0.18739921],
#         [0.04276217],
#         [0.09055454],
#         [0.05946971],
#         [0.07621392],
#         [0.24255027],
#         [0.2906466 ],
#         [0.19515671],
#         [0.09736931],
#         [0.08378265],
#         [0.05769407],
#         [0.07376361],
#         [0.21159692],
#         [0.3239852 ],
#         [0.20652448],
#         [0.18461338],
#         [0.06486109],
#         [0.04350445],
#         [0.04172513],
#         [0.20214105],
#         [0.20949988],
#         [0.07341936],
#         [0.07804539],
#         [0.04541996],
#         [0.04735974],
#         [0.02056655],
#         [0.3225932 ],
#         [0.5577579 ],
#         [0.212256  ],
#         [0.02943815],
#         [0.04051626],
#         [0.04254787],
#         [0.02873898],
#         [0.12283368],
#         [0.28215015],
#         [0.15464212],
#         [0.04741085],
#         [0.06068139],
#         [0.08538669],
#         [0.07590912],
#         [0.09332043],
#         [0.1272098 ],
#         [0.08511401],
#         [0.02582845],
#         [0.06297805],
#         [0.04857281],
#         [0.05934889],
#         [0.04582703],
#         [0.11350149],
#         [0.08761443],
#         [0.02474828],
#         [0.06641921],
#         [0.04809885],
#         [0.07683792],
#         [0.12583901],
#         [0.19031434],
#         [0.07268047],
#         [0.01593597],
#         [0.05378374],
#         [0.04007751],
#         [0.08062802],
#         [0.05498745],
#         [0.06570322],
#         [0.0757435 ],
#         [0.03684987],
#         [0.09732814],
#         [0.05663175],
#         [0.08547595],
#         [0.07802016],
#         [0.08790946],
#         [0.05613997],
#         [0.06084843],
#         [0.13038331],
#         [0.08885407],
#         [0.11880019],
#         [0.25552577],
#         [0.13373254],
#         [0.07135345],
#         [0.20382738],
#         [0.06606457],
#         [0.09285879],
#         [0.14488567],
#         [0.346737  ],
#         [0.16964158],
#         [0.06914863],
#         [0.03902222],
#         [0.04885583],
#         [0.10828291],
#         [0.05490699],
#         [0.07070327],
#         [0.03460685],
#         [0.06791496],
#         [0.01280333],
#         [0.01318277],
#         [0.07092224],
#         [0.12614438],
#         [0.09550399],
#         [0.02011053],
#         [0.08130875],
#         [0.016427  ],
#         [0.03456626],
#         [0.15861213],
#         [0.30510855],
#         [0.22221383],
#         [0.0122784 ],
#         [0.06967725],
#         [0.0336892 ],
#         [0.03036228],
#         [0.10171808],
#         [0.17105143],
#         [0.07475448],
#         [0.03077991],
#         [0.49604514],
#         [0.07995968],
#         [0.06184696],
#         [0.18665639],
#         [0.1098616 ],
#         [0.04156027],
#         [0.00730768],
#         [0.07481718],
#         [0.04338912],
#         [0.01709717],
#         [0.09585632],
#         [0.09582989],
#         [0.04654995],
#         [0.00870353],
#         [0.03141086],
#         [0.01775522],
#         [0.01955784],
#         [0.24025351],
#         [0.3241142 ],
#         [0.12908982],
#         [0.00939581],
#         [0.027481  ],
#         [0.02310291],
#         [0.04170391],
#         [0.06642389],
#         [0.17216584],
#         [0.08622466],
#         [0.0368483 ],
#         [0.03701133],
#         [0.02808704],
#         [0.05509818],
#         [0.3443353 ],
#         [0.6188419 ],
#         [0.08834747],
#         [0.23119844],
#         [0.02416459],
#         [0.03125603],
#         [0.17274694],
#         [0.24768567],
#         [0.17640997],
#         [0.05692165],
#         [0.19311696],
#         [0.07026498],
#         [0.10281935],
#         [0.06067796],
#         [0.04522929],
#         [0.08407477],
#         [0.03338514],
#         [0.04365316],
#         [0.21489272],
#         [0.29751503],
#         [0.17384283],
#         [0.01892927],
#         [0.0680089 ],
#         [0.17659768],
#         [0.09005791],
#         [0.17379811],
#         [0.20619054],
#         [0.23018533],
#         [0.03054039],
#         [0.04943025],
#         [0.03004153],
#         [0.08496704],
#         [0.19819622],
#         [0.35617003],
#         [0.27944314],
#         [0.18382278],
#         [0.20150167],
#         [0.32973665],
#         [0.353211  ],
#         [0.50244397],
#         [0.70635927],
#         [0.38560748],
#         [0.04179015],
#         [0.04042816],
#         [0.10992445],
#         [0.2681326 ],
#         [0.17209531],
#         [0.04014937],
#         [0.02693358],
#         [0.01109643],
#         [0.01661798],
#         [0.05015564],
#         [0.07351714],
#         [0.04962144],
#         [0.02823059],
#         [0.14278018],
#         [0.21740508],
#         [0.1465271 ],
#         [0.16430782],
#         [0.2988163 ],
#         [0.2306462 ],
#         [0.01719494],
#         [0.05566894],
#         [0.02025895],
#         [0.0239216 ],
#         [0.05231864],
#         [0.18501256],
#         [0.1176734 ],
#         [0.04633667],
#         [0.05657919],
#         [0.01092019],
#         [0.04961531],
#         [0.09228183],
#         [0.15289713],
#         [0.09949905],
#         [0.029812  ],
#         [0.06503432],
#         [0.01994206],
#         [0.12140725],
#         [0.24065305],
#         [0.28752893],
#         [0.1091546 ],
#         [0.03527984],
#         [0.07621028],
#         [0.01717583],
#         [0.05018301],
#         [0.25968722],
#         [0.32605484],
#         [0.29163134],
#         [0.02447897],
#         [0.04475191],
#         [0.0187141 ],
#         [0.04765438],
#         [0.1267862 ],
#         [0.20693782],
#         [0.13339283],
#         [0.03296305],
#         [0.03874182],
#         [0.02051977],
#         [0.02751393],
#         [0.3582851 ],
#         [0.42422512],
#         [0.0490262 ],
#         [0.07063574],
#         [0.04774337],
#         [0.03420897],
#         [0.30128345],
#         [0.35815394],
#         [0.24697945],
#         [0.02307169],
#         [0.12336306],
#         [0.12321639],
#         [0.13146257],
#         [0.18659757],
#         [0.34143335],
#         [0.20625795],
#         [0.01992827],
#         [0.11450326],
#         [0.04698755],
#         [0.24847807],
#         [0.3565912 ],
#         [0.23435324],
#         [0.1688055 ],
#         [0.04406803],
#         [0.0365666 ],
#         [0.03798388],
#         [0.08272469],
#         [0.08403612],
#         [0.5520213 ],
#         [0.08995396],
#         [0.08992916],
#         [0.06251276],
#         [0.19254488],
#         [0.34100485],
#         [0.55410683],
#         [0.35872412],
#         [0.10985678],
#         [0.12172119],
#         [0.30674654],
#         [0.46564978],
#         [0.822918  ],
#         [0.48146608],
#         [0.03383821],
#         [0.15084083],
#         [0.09046553],
#         [0.22345297],
#         [0.25399584],
#         [0.13337867]], dtype=float32), array([[0.06510483],
#         [0.09154754],
#         [0.02079828],
#         [0.01946098],
#         [0.15289503],
#         [0.2894396 ],
#         [0.18390737],
#         [0.10439999],
#         [0.09284486],
#         [0.02716608],
#         [0.04427543],
#         [0.16616952],
#         [0.22676839],
#         [0.19789751],
#         [0.09335691],
#         [0.10381002],
#         [0.0158987 ],
#         [0.03368955],
#         [0.16758312],
#         [0.16722128],
#         [0.1473026 ],
#         [0.04639239],
#         [0.2065264 ],
#         [0.01593596],
#         [0.05056714],
#         [0.2081313 ],
#         [0.19105412],
#         [0.25064963],
#         [0.04173984],
#         [0.1577709 ],
#         [0.01590519],
#         [0.0205163 ],
#         [0.20139891],
#         [0.17489699],
#         [0.13265803],
#         [0.04974325],
#         [0.08195568],
#         [0.04875813],
#         [0.0242376 ],
#         [0.17152722],
#         [0.17002186],
#         [0.1712566 ],
#         [0.09657023],
#         [0.07963794],
#         [0.08120664],
#         [0.02217174],
#         [0.17432596],
#         [0.17426306],
#         [0.20822795],
#         [0.15447146],
#         [0.06176495],
#         [0.07736871],
#         [0.02406977],
#         [0.16070999],
#         [0.14765032],
#         [0.20561878],
#         [0.1444418 ],
#         [0.03246988],
#         [0.06594636],
#         [0.0279169 ],
#         [0.14943369],
#         [0.1755297 ],
#         [0.15454096],
#         [0.1818211 ],
#         [0.01464286],
#         [0.06011701],
#         [0.03079773],
#         [0.12834483],
#         [0.2181499 ],
#         [0.12030371],
#         [0.21763344],
#         [0.01331995],
#         [0.05536871],
#         [0.03555666],
#         [0.1368812 ],
#         [0.18735597],
#         [0.06756663],
#         [0.15114897],
#         [0.0125346 ],
#         [0.01709115],
#         [0.04038757],
#         [0.11694726],
#         [0.11162777],
#         [0.03313809],
#         [0.13072337],
#         [0.01846212],
#         [0.02788374],
#         [0.07493345],
#         [0.05553231],
#         [0.10606148],
#         [0.02035426],
#         [0.10811981],
#         [0.02706376],
#         [0.01643783],
#         [0.07953992],
#         [0.06041415],
#         [0.06312928],
#         [0.02518063],
#         [0.09447495],
#         [0.02556664],
#         [0.02896907],
#         [0.19121246],
#         [0.1557228 ],
#         [0.11602133],
#         [0.01524312],
#         [0.02363891],
#         [0.01873159],
#         [0.03060647],
#         [0.16595931],
#         [0.1648568 ],
#         [0.11644375],
#         [0.05560388],
#         [0.05121887],
#         [0.02549944]], dtype=float32), MinMaxScaler(copy=True, feature_range=(0, 1)))

# %% [markdown]
# ## PREDICCIÓN
# - Haciendo uso del mejor modelo (de acuerdo a correlación y estabilidad)

# %%
## EJECUCIÓN DE LA FUNCIÓN DE CONSTRUCCIÓN, ENTRENAMIENTO Y TEST DE LA RED
model1, trainPredict1, testPredict1, scaler1 = execute_lstm(unidades, date, look_back=90, neuronas=200, epocas=200, capas=6, training_split=0.7,optimizacion='adam', act='tanh')

#
# Out:
# 685 294
# Epoch 1/200
# 19/19 - 10s - loss: 0.0220 - 10s/epoch - 551ms/step
# Epoch 2/200
# 19/19 - 0s - loss: 0.0179 - 377ms/epoch - 20ms/step
# Epoch 3/200
# 19/19 - 0s - loss: 0.0177 - 470ms/epoch - 25ms/step
# Epoch 4/200
# 19/19 - 0s - loss: 0.0176 - 464ms/epoch - 24ms/step
# Epoch 5/200
# 19/19 - 0s - loss: 0.0177 - 487ms/epoch - 26ms/step
# Epoch 6/200
# 19/19 - 1s - loss: 0.0177 - 567ms/epoch - 30ms/step
# Epoch 7/200
# 19/19 - 1s - loss: 0.0177 - 556ms/epoch - 29ms/step
# Epoch 8/200
# 19/19 - 0s - loss: 0.0177 - 482ms/epoch - 25ms/step
# Epoch 9/200
# 19/19 - 0s - loss: 0.0177 - 445ms/epoch - 23ms/step
# Epoch 10/200
# 19/19 - 0s - loss: 0.0177 - 414ms/epoch - 22ms/step
# Epoch 11/200
# 19/19 - 0s - loss: 0.0177 - 379ms/epoch - 20ms/step
# Epoch 12/200
# 19/19 - 0s - loss: 0.0177 - 374ms/epoch - 20ms/step
# Epoch 13/200
# 19/19 - 0s - loss: 0.0177 - 410ms/epoch - 22ms/step
# Epoch 14/200
# 19/19 - 0s - loss: 0.0177 - 382ms/epoch - 20ms/step
# Epoch 15/200
# 19/19 - 0s - loss: 0.0177 - 326ms/epoch - 17ms/step
# Epoch 16/200
# 19/19 - 0s - loss: 0.0176 - 332ms/epoch - 17ms/step
# Epoch 17/200
# 19/19 - 0s - loss: 0.0177 - 326ms/epoch - 17ms/step
# Epoch 18/200
# 19/19 - 0s - loss: 0.0177 - 328ms/epoch - 17ms/step
# Epoch 19/200
# 19/19 - 0s - loss: 0.0177 - 325ms/epoch - 17ms/step
# Epoch 20/200
# 19/19 - 0s - loss: 0.0177 - 321ms/epoch - 17ms/step
# Epoch 21/200
# 19/19 - 0s - loss: 0.0177 - 348ms/epoch - 18ms/step
# Epoch 22/200
# 19/19 - 0s - loss: 0.0177 - 367ms/epoch - 19ms/step
# Epoch 23/200
# 19/19 - 0s - loss: 0.0176 - 333ms/epoch - 18ms/step
# Epoch 24/200
# 19/19 - 0s - loss: 0.0174 - 317ms/epoch - 17ms/step
# Epoch 25/200
# 19/19 - 0s - loss: 0.0172 - 312ms/epoch - 16ms/step
# Epoch 26/200
# 19/19 - 0s - loss: 0.0175 - 345ms/epoch - 18ms/step
# Epoch 27/200
# 19/19 - 0s - loss: 0.0173 - 321ms/epoch - 17ms/step
# Epoch 28/200
# 19/19 - 0s - loss: 0.0156 - 292ms/epoch - 15ms/step
# Epoch 29/200
# 19/19 - 0s - loss: 0.0151 - 322ms/epoch - 17ms/step
# Epoch 30/200
# 19/19 - 0s - loss: 0.0149 - 313ms/epoch - 16ms/step
# Epoch 31/200
# 19/19 - 0s - loss: 0.0155 - 340ms/epoch - 18ms/step
# Epoch 32/200
# 19/19 - 0s - loss: 0.0153 - 346ms/epoch - 18ms/step
# Epoch 33/200
# 19/19 - 0s - loss: 0.0147 - 326ms/epoch - 17ms/step
# Epoch 34/200
# 19/19 - 0s - loss: 0.0149 - 331ms/epoch - 17ms/step
# Epoch 35/200
# 19/19 - 0s - loss: 0.0146 - 378ms/epoch - 20ms/step
# Epoch 36/200
# 19/19 - 0s - loss: 0.0144 - 348ms/epoch - 18ms/step
# Epoch 37/200
# 19/19 - 0s - loss: 0.0148 - 328ms/epoch - 17ms/step
# Epoch 38/200
# 19/19 - 0s - loss: 0.0143 - 350ms/epoch - 18ms/step
# Epoch 39/200
# 19/19 - 0s - loss: 0.0144 - 350ms/epoch - 18ms/step
# Epoch 40/200
# 19/19 - 0s - loss: 0.0141 - 355ms/epoch - 19ms/step
# Epoch 41/200
# 19/19 - 0s - loss: 0.0144 - 337ms/epoch - 18ms/step
# Epoch 42/200
# 19/19 - 0s - loss: 0.0143 - 333ms/epoch - 18ms/step
# Epoch 43/200
# 19/19 - 0s - loss: 0.0143 - 328ms/epoch - 17ms/step
# Epoch 44/200
# 19/19 - 0s - loss: 0.0140 - 325ms/epoch - 17ms/step
# Epoch 45/200
# 19/19 - 0s - loss: 0.0139 - 359ms/epoch - 19ms/step
# Epoch 46/200
# 19/19 - 0s - loss: 0.0141 - 356ms/epoch - 19ms/step
# Epoch 47/200
# 19/19 - 0s - loss: 0.0137 - 330ms/epoch - 17ms/step
# Epoch 48/200
# 19/19 - 0s - loss: 0.0136 - 342ms/epoch - 18ms/step
# Epoch 49/200
# 19/19 - 0s - loss: 0.0140 - 321ms/epoch - 17ms/step
# Epoch 50/200
# 19/19 - 0s - loss: 0.0134 - 322ms/epoch - 17ms/step
# Epoch 51/200
# 19/19 - 0s - loss: 0.0135 - 307ms/epoch - 16ms/step
# Epoch 52/200
# 19/19 - 0s - loss: 0.0136 - 320ms/epoch - 17ms/step
# Epoch 53/200
# 19/19 - 0s - loss: 0.0133 - 328ms/epoch - 17ms/step
# Epoch 54/200
# 19/19 - 0s - loss: 0.0137 - 318ms/epoch - 17ms/step
# Epoch 55/200
# 19/19 - 0s - loss: 0.0131 - 325ms/epoch - 17ms/step
# Epoch 56/200
# 19/19 - 0s - loss: 0.0142 - 345ms/epoch - 18ms/step
# Epoch 57/200
# 19/19 - 0s - loss: 0.0143 - 348ms/epoch - 18ms/step
# Epoch 58/200
# 19/19 - 0s - loss: 0.0135 - 323ms/epoch - 17ms/step
# Epoch 59/200
# 19/19 - 0s - loss: 0.0131 - 304ms/epoch - 16ms/step
# Epoch 60/200
# 19/19 - 0s - loss: 0.0133 - 368ms/epoch - 19ms/step
# Epoch 61/200
# 19/19 - 0s - loss: 0.0129 - 329ms/epoch - 17ms/step
# Epoch 62/200
# 19/19 - 0s - loss: 0.0134 - 342ms/epoch - 18ms/step
# Epoch 63/200
# 19/19 - 0s - loss: 0.0136 - 358ms/epoch - 19ms/step
# Epoch 64/200
# 19/19 - 0s - loss: 0.0137 - 354ms/epoch - 19ms/step
# Epoch 65/200
# 19/19 - 0s - loss: 0.0138 - 301ms/epoch - 16ms/step
# Epoch 66/200
# 19/19 - 0s - loss: 0.0134 - 331ms/epoch - 17ms/step
# Epoch 67/200
# 19/19 - 0s - loss: 0.0129 - 344ms/epoch - 18ms/step
# Epoch 68/200
# 19/19 - 0s - loss: 0.0126 - 337ms/epoch - 18ms/step
# Epoch 69/200
# 19/19 - 0s - loss: 0.0125 - 342ms/epoch - 18ms/step
# Epoch 70/200
# 19/19 - 0s - loss: 0.0125 - 323ms/epoch - 17ms/step
# Epoch 71/200
# 19/19 - 0s - loss: 0.0123 - 362ms/epoch - 19ms/step
# Epoch 72/200
# 19/19 - 0s - loss: 0.0121 - 330ms/epoch - 17ms/step
# Epoch 73/200
# 19/19 - 0s - loss: 0.0127 - 296ms/epoch - 16ms/step
# Epoch 74/200
# 19/19 - 0s - loss: 0.0121 - 296ms/epoch - 16ms/step
# Epoch 75/200
# 19/19 - 0s - loss: 0.0121 - 317ms/epoch - 17ms/step
# Epoch 76/200
# 19/19 - 0s - loss: 0.0136 - 296ms/epoch - 16ms/step
# Epoch 77/200
# 19/19 - 0s - loss: 0.0120 - 311ms/epoch - 16ms/step
# Epoch 78/200
# 19/19 - 0s - loss: 0.0114 - 344ms/epoch - 18ms/step
# Epoch 79/200
# 19/19 - 0s - loss: 0.0115 - 315ms/epoch - 17ms/step
# Epoch 80/200
# 19/19 - 0s - loss: 0.0117 - 336ms/epoch - 18ms/step
# Epoch 81/200
# 19/19 - 0s - loss: 0.0118 - 324ms/epoch - 17ms/step
# Epoch 82/200
# 19/19 - 0s - loss: 0.0127 - 299ms/epoch - 16ms/step
# Epoch 83/200
# 19/19 - 0s - loss: 0.0127 - 350ms/epoch - 18ms/step
# Epoch 84/200
# 19/19 - 0s - loss: 0.0116 - 323ms/epoch - 17ms/step
# Epoch 85/200
# 19/19 - 0s - loss: 0.0118 - 327ms/epoch - 17ms/step
# Epoch 86/200
# 19/19 - 0s - loss: 0.0120 - 384ms/epoch - 20ms/step
# Epoch 87/200
# 19/19 - 0s - loss: 0.0116 - 356ms/epoch - 19ms/step
# Epoch 88/200
# 19/19 - 0s - loss: 0.0112 - 306ms/epoch - 16ms/step
# Epoch 89/200
# 19/19 - 0s - loss: 0.0109 - 321ms/epoch - 17ms/step
# Epoch 90/200
# 19/19 - 0s - loss: 0.0104 - 328ms/epoch - 17ms/step
# Epoch 91/200
# 19/19 - 0s - loss: 0.0104 - 318ms/epoch - 17ms/step
# Epoch 92/200
# 19/19 - 0s - loss: 0.0104 - 358ms/epoch - 19ms/step
# Epoch 93/200
# 19/19 - 0s - loss: 0.0101 - 322ms/epoch - 17ms/step
# Epoch 94/200
# 19/19 - 0s - loss: 0.0100 - 330ms/epoch - 17ms/step
# Epoch 95/200
# 19/19 - 0s - loss: 0.0104 - 350ms/epoch - 18ms/step
# Epoch 96/200
# 19/19 - 0s - loss: 0.0104 - 361ms/epoch - 19ms/step
# Epoch 97/200
# 19/19 - 0s - loss: 0.0098 - 346ms/epoch - 18ms/step
# Epoch 98/200
# 19/19 - 0s - loss: 0.0102 - 335ms/epoch - 18ms/step
# Epoch 99/200
# 19/19 - 0s - loss: 0.0099 - 339ms/epoch - 18ms/step
# Epoch 100/200
# 19/19 - 0s - loss: 0.0097 - 307ms/epoch - 16ms/step
# Epoch 101/200
# 19/19 - 0s - loss: 0.0099 - 340ms/epoch - 18ms/step
# Epoch 102/200
# 19/19 - 0s - loss: 0.0111 - 319ms/epoch - 17ms/step
# Epoch 103/200
# 19/19 - 0s - loss: 0.0106 - 326ms/epoch - 17ms/step
# Epoch 104/200
# 19/19 - 0s - loss: 0.0103 - 341ms/epoch - 18ms/step
# Epoch 105/200
# 19/19 - 0s - loss: 0.0098 - 343ms/epoch - 18ms/step
# Epoch 106/200
# 19/19 - 0s - loss: 0.0096 - 311ms/epoch - 16ms/step
# Epoch 107/200
# 19/19 - 0s - loss: 0.0095 - 318ms/epoch - 17ms/step
# Epoch 108/200
# 19/19 - 0s - loss: 0.0095 - 336ms/epoch - 18ms/step
# Epoch 109/200
# 19/19 - 0s - loss: 0.0096 - 306ms/epoch - 16ms/step
# Epoch 110/200
# 19/19 - 0s - loss: 0.0101 - 344ms/epoch - 18ms/step
# Epoch 111/200
# 19/19 - 0s - loss: 0.0096 - 318ms/epoch - 17ms/step
# Epoch 112/200
# 19/19 - 0s - loss: 0.0095 - 329ms/epoch - 17ms/step
# Epoch 113/200
# 19/19 - 0s - loss: 0.0093 - 341ms/epoch - 18ms/step
# Epoch 114/200
# 19/19 - 0s - loss: 0.0095 - 345ms/epoch - 18ms/step
# Epoch 115/200
# 19/19 - 0s - loss: 0.0091 - 324ms/epoch - 17ms/step
# Epoch 116/200
# 19/19 - 0s - loss: 0.0086 - 380ms/epoch - 20ms/step
# Epoch 117/200
# 19/19 - 0s - loss: 0.0085 - 340ms/epoch - 18ms/step
# Epoch 118/200
# 19/19 - 0s - loss: 0.0088 - 328ms/epoch - 17ms/step
# Epoch 119/200
# 19/19 - 0s - loss: 0.0100 - 345ms/epoch - 18ms/step
# Epoch 120/200
# 19/19 - 0s - loss: 0.0101 - 348ms/epoch - 18ms/step
# Epoch 121/200
# 19/19 - 0s - loss: 0.0086 - 360ms/epoch - 19ms/step
# Epoch 122/200
# 19/19 - 0s - loss: 0.0085 - 312ms/epoch - 16ms/step
# Epoch 123/200
# 19/19 - 0s - loss: 0.0088 - 335ms/epoch - 18ms/step
# Epoch 124/200
# 19/19 - 0s - loss: 0.0099 - 313ms/epoch - 16ms/step
# Epoch 125/200
# 19/19 - 0s - loss: 0.0096 - 319ms/epoch - 17ms/step
# Epoch 126/200
# 19/19 - 0s - loss: 0.0090 - 328ms/epoch - 17ms/step
# Epoch 127/200
# 19/19 - 0s - loss: 0.0088 - 313ms/epoch - 16ms/step
# Epoch 128/200
# 19/19 - 0s - loss: 0.0084 - 327ms/epoch - 17ms/step
# Epoch 129/200
# 19/19 - 0s - loss: 0.0084 - 336ms/epoch - 18ms/step
# Epoch 130/200
# 19/19 - 0s - loss: 0.0084 - 329ms/epoch - 17ms/step
# Epoch 131/200
# 19/19 - 0s - loss: 0.0082 - 354ms/epoch - 19ms/step
# Epoch 132/200
# 19/19 - 0s - loss: 0.0087 - 345ms/epoch - 18ms/step
# Epoch 133/200
# 19/19 - 0s - loss: 0.0091 - 343ms/epoch - 18ms/step
# Epoch 134/200
# 19/19 - 0s - loss: 0.0093 - 331ms/epoch - 17ms/step
# Epoch 135/200
# 19/19 - 0s - loss: 0.0088 - 325ms/epoch - 17ms/step
# Epoch 136/200
# 19/19 - 0s - loss: 0.0089 - 331ms/epoch - 17ms/step
# Epoch 137/200
# 19/19 - 0s - loss: 0.0085 - 328ms/epoch - 17ms/step
# Epoch 138/200
# 19/19 - 0s - loss: 0.0082 - 367ms/epoch - 19ms/step
# Epoch 139/200
# 19/19 - 0s - loss: 0.0093 - 333ms/epoch - 18ms/step
# Epoch 140/200
# 19/19 - 0s - loss: 0.0090 - 341ms/epoch - 18ms/step
# Epoch 141/200
# 19/19 - 0s - loss: 0.0079 - 357ms/epoch - 19ms/step
# Epoch 142/200
# 19/19 - 0s - loss: 0.0082 - 338ms/epoch - 18ms/step
# Epoch 143/200
# 19/19 - 0s - loss: 0.0080 - 313ms/epoch - 16ms/step
# Epoch 144/200
# 19/19 - 0s - loss: 0.0079 - 346ms/epoch - 18ms/step
# Epoch 145/200
# 19/19 - 0s - loss: 0.0086 - 376ms/epoch - 20ms/step
# Epoch 146/200
# 19/19 - 0s - loss: 0.0081 - 363ms/epoch - 19ms/step
# Epoch 147/200
# 19/19 - 0s - loss: 0.0080 - 341ms/epoch - 18ms/step
# Epoch 148/200
# 19/19 - 0s - loss: 0.0079 - 346ms/epoch - 18ms/step
# Epoch 149/200
# 19/19 - 0s - loss: 0.0081 - 326ms/epoch - 17ms/step
# Epoch 150/200
# 19/19 - 0s - loss: 0.0080 - 312ms/epoch - 16ms/step
# Epoch 151/200
# 19/19 - 0s - loss: 0.0079 - 309ms/epoch - 16ms/step
# Epoch 152/200
# 19/19 - 0s - loss: 0.0081 - 328ms/epoch - 17ms/step
# Epoch 153/200
# 19/19 - 0s - loss: 0.0077 - 320ms/epoch - 17ms/step
# Epoch 154/200
# 19/19 - 0s - loss: 0.0079 - 339ms/epoch - 18ms/step
# Epoch 155/200
# 19/19 - 0s - loss: 0.0077 - 322ms/epoch - 17ms/step
# Epoch 156/200
# 19/19 - 0s - loss: 0.0083 - 333ms/epoch - 18ms/step
# Epoch 157/200
# 19/19 - 0s - loss: 0.0079 - 335ms/epoch - 18ms/step
# Epoch 158/200
# 19/19 - 0s - loss: 0.0077 - 353ms/epoch - 19ms/step
# Epoch 159/200
# 19/19 - 0s - loss: 0.0079 - 366ms/epoch - 19ms/step
# Epoch 160/200
# 19/19 - 0s - loss: 0.0078 - 377ms/epoch - 20ms/step
# Epoch 161/200
# 19/19 - 1s - loss: 0.0085 - 505ms/epoch - 27ms/step
# Epoch 162/200
# 19/19 - 0s - loss: 0.0083 - 459ms/epoch - 24ms/step
# Epoch 163/200
# 19/19 - 0s - loss: 0.0080 - 336ms/epoch - 18ms/step
# Epoch 164/200
# 19/19 - 1s - loss: 0.0078 - 581ms/epoch - 31ms/step
# Epoch 165/200
# 19/19 - 1s - loss: 0.0078 - 644ms/epoch - 34ms/step
# Epoch 166/200
# 19/19 - 0s - loss: 0.0079 - 474ms/epoch - 25ms/step
# Epoch 167/200
# 19/19 - 0s - loss: 0.0075 - 385ms/epoch - 20ms/step
# Epoch 168/200
# 19/19 - 0s - loss: 0.0079 - 351ms/epoch - 18ms/step
# Epoch 169/200
# 19/19 - 0s - loss: 0.0082 - 389ms/epoch - 20ms/step
# Epoch 170/200
# 19/19 - 0s - loss: 0.0076 - 396ms/epoch - 21ms/step
# Epoch 171/200
# 19/19 - 0s - loss: 0.0075 - 463ms/epoch - 24ms/step
# Epoch 172/200
# 19/19 - 0s - loss: 0.0076 - 405ms/epoch - 21ms/step
# Epoch 173/200
# 19/19 - 0s - loss: 0.0075 - 403ms/epoch - 21ms/step
# Epoch 174/200
# 19/19 - 0s - loss: 0.0078 - 500ms/epoch - 26ms/step
# Epoch 175/200
# 19/19 - 0s - loss: 0.0079 - 343ms/epoch - 18ms/step
# Epoch 176/200
# 19/19 - 0s - loss: 0.0075 - 491ms/epoch - 26ms/step
# Epoch 177/200
# 19/19 - 0s - loss: 0.0083 - 458ms/epoch - 24ms/step
# Epoch 178/200
# 19/19 - 0s - loss: 0.0073 - 318ms/epoch - 17ms/step
# Epoch 179/200
# 19/19 - 1s - loss: 0.0074 - 508ms/epoch - 27ms/step
# Epoch 180/200
# 19/19 - 0s - loss: 0.0083 - 325ms/epoch - 17ms/step
# Epoch 181/200
# 19/19 - 0s - loss: 0.0082 - 376ms/epoch - 20ms/step
# Epoch 182/200
# 19/19 - 0s - loss: 0.0081 - 327ms/epoch - 17ms/step
# Epoch 183/200
# 19/19 - 0s - loss: 0.0075 - 346ms/epoch - 18ms/step
# Epoch 184/200
# 19/19 - 0s - loss: 0.0074 - 363ms/epoch - 19ms/step
# Epoch 185/200
# 19/19 - 0s - loss: 0.0083 - 333ms/epoch - 18ms/step
# Epoch 186/200
# 19/19 - 0s - loss: 0.0080 - 346ms/epoch - 18ms/step
# Epoch 187/200
# 19/19 - 0s - loss: 0.0076 - 332ms/epoch - 17ms/step
# Epoch 188/200
# 19/19 - 0s - loss: 0.0075 - 328ms/epoch - 17ms/step
# Epoch 189/200
# 19/19 - 0s - loss: 0.0076 - 347ms/epoch - 18ms/step
# Epoch 190/200
# 19/19 - 0s - loss: 0.0081 - 367ms/epoch - 19ms/step
# Epoch 191/200
# 19/19 - 0s - loss: 0.0073 - 339ms/epoch - 18ms/step
# Epoch 192/200
# 19/19 - 0s - loss: 0.0069 - 352ms/epoch - 19ms/step
# Epoch 193/200
# 19/19 - 0s - loss: 0.0074 - 363ms/epoch - 19ms/step
# Epoch 194/200
# 19/19 - 0s - loss: 0.0075 - 365ms/epoch - 19ms/step
# Epoch 195/200
# 19/19 - 0s - loss: 0.0091 - 346ms/epoch - 18ms/step
# Epoch 196/200
# 19/19 - 0s - loss: 0.0080 - 328ms/epoch - 17ms/step
# Epoch 197/200
# 19/19 - 0s - loss: 0.0081 - 306ms/epoch - 16ms/step
# Epoch 198/200
# 19/19 - 0s - loss: 0.0073 - 340ms/epoch - 18ms/step
# Epoch 199/200
# 19/19 - 0s - loss: 0.0074 - 317ms/epoch - 17ms/step
# Epoch 200/200
# 19/19 - 0s - loss: 0.0077 - 326ms/epoch - 17ms/step
# Test Score: 0.45 CORRELACION

# %%
# DATOS DEL MES DE NOVIEMBRE A PREDECIR
predict_data1 = pandas.read_csv('data/INPUT_DATA_PREDICT_180.CSV')
scaler = MinMaxScaler(feature_range=(0, 1))
unidades1 = scaler.fit_transform(unidades)

# %%
predict_data1 = predict_data1.values
predict_data1 = predict_data1.astype('float32')

# %%
#se define lookback igual al usado en modelo neuronal
look_back1 = 90
predict_data_lookback1, predict_data_tiempo_actual1  = create_dataset(predict_data1, look_back1)

# %%
predict_data_lookback1 = numpy.reshape(predict_data_lookback1, (predict_data_lookback1.shape[0], 1, predict_data_lookback1.shape[1]))
#Predicción
predict_model1 = model1.predict(predict_data_lookback1)

# %%
predict_model1
# Out:
# array([[0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152195],
#        [0.07152195],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152195],
#        [0.07152195],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152195],
#        [0.07152195],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196],
#        [0.07152196]], dtype=float32)

# %%
trainPredictPlot = numpy.empty_like(unidades)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back1:len(trainPredict1) + look_back1, :] = trainPredict1

# %%
testPredictPlot = numpy.empty_like(unidades)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict1) + (look_back1 * 2) - 1 :len(unidades) - 1, :] = testPredict1

# %%
plt.plot(unidades1)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.title("Primer Modelo LSTM escogido")
plt.ylabel("Unidades de Carne Vendidas")
plt.xlabel("Tiempo")
plt.show()
